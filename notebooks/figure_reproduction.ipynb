# %% [markdown]
# # Figure reproduction
# Run `python scripts/07_generate_figures.py` after placing processed inputs per `data/README.md`.
# Figures are regenerated from saved fold-level predictions; no raw data are bundled.
